# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
json_file = "characters.json"
characters_df = pd.read_json(json_file)
characters_df.head()
# Out:
#                actor  alive    ancestry dateOfBirth eyeColour  gender  \
# 0   Daniel Radcliffe   True  half-blood  31-07-1980     green    male
# 1        Emma Watson   True  muggleborn  19-09-1979     brown  female
# 2       Rupert Grint   True  pure-blood  01-03-1980      blue    male
# 3         Tom Felton   True  pure-blood  05-06-1980      grey    male
# 4  Dame Maggie Smith   True              04-10-1925            female
#
#   hairColour  hogwartsStaff  hogwartsStudent       house  \
# 0      black          False             True  Gryffindor
# 1      brown          False             True  Gryffindor
# 2        red          False             True  Gryffindor
# 3     blonde          False             True   Slytherin
# 4      black           True            False  Gryffindor
#
#                                                image                name  \
# 0       http://hp-api.herokuapp.com/images/harry.jpg        Harry Potter
# ...

# %%
characters_df_new = characters_df[["name", "yearOfBirth", "house", "ancestry", "eyeColour", "gender", "hogwartsStaff", "hogwartsStudent", "species", "alive"]].copy().reset_index()
characters_df_new
# Out:
#     index                  name yearOfBirth       house    ancestry eyeColour  \
# 0       0          Harry Potter        1980  Gryffindor  half-blood     green
# 1       1      Hermione Granger        1979  Gryffindor  muggleborn     brown
# 2       2           Ron Weasley        1980  Gryffindor  pure-blood      blue
# 3       3          Draco Malfoy        1980   Slytherin  pure-blood      grey
# 4       4    Minerva McGonagall        1925  Gryffindor
# 5       5        Cedric Diggory        1977  Hufflepuff                  grey
# 6       6             Cho Chang               Ravenclaw                 brown
# 7       7         Severus Snape        1960   Slytherin  half-blood     black
# 8       8         Rubeus Hagrid        1928  Gryffindor  half-blood     black
# 9       9    Neville Longbottom        1980  Gryffindor  pure-blood
# 10     10         Luna Lovegood        1981   Ravenclaw                  grey
# ...

# %%
characters_df_new.columns = ["id", "name", "yearOfBirth", "house", "ancestry", "eyeColour", "gender", "hogwartsStaff", "hogwartsStudent", "species", "alive"]
characters_df_new.head()
# Out:
#    id                name yearOfBirth       house    ancestry eyeColour  \
# 0   0        Harry Potter        1980  Gryffindor  half-blood     green
# 1   1    Hermione Granger        1979  Gryffindor  muggleborn     brown
# 2   2         Ron Weasley        1980  Gryffindor  pure-blood      blue
# 3   3        Draco Malfoy        1980   Slytherin  pure-blood      grey
# 4   4  Minerva McGonagall        1925  Gryffindor
#
#    gender  hogwartsStaff  hogwartsStudent species  alive
# 0    male          False             True   human   True
# 1  female          False             True   human   True
# 2    male          False             True   human   True
# 3    male          False             True   human   True
# 4  female           True            False   human   True
